# %%
# KoNLPy(Korean Natural Language Python)
#   Java를 사용 -> Java가 설치되어있어야
#   Python에서 Java를 활용할 수 있게 : jpype

# %pip install JPype1
# %pip install konlpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 49.6 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 110.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [konlpy]2m1/2 [konlpy]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sentence = "네네 집체를 교육시간으로 보고 비대면은 그냥 프로젝트 멘토링으로 생각해도 될듯해요."
sentence += " 클라우드 환경위에 ai 플랫폼 구성해서 사업하고있는듯 해요."
sentence += " 선생님 봤을때 이거 난이도가 어때요?"
sentence += " 비전공자 기준과, 우리 개발자 과정 수료생 듣는다 했을때?"
sentence += " 에이ㅋㅋㅋㅋ"

from konlpy.tag import Okt

o = Okt() # Open Korean Text분석기(구 트위터한글형태소분석기)

a = o.normalize(sentence) # 정규화(정리)
print(a)

b = o.phrases(sentence) # 어구 추출(의미있는 단위로 나누기)
print(b)

c = o.morphs(sentence) # 형태소 분석(합성어같은것도 나누기)
print(c)

d = o.morphs(sentence, stem=True) # 형태소 분석(합성어같은것도 나누기 + 동사원형)
print(d)

e = o.pos(sentence) # 형태소 분석(합성어같은것도 나누기) + 품사 태깅 : (단어, 품사)
# for word, poomsa in e:
#     print(word, poomsa)
print("-----")

f = o.pos(sentence, join=True) # 형태소 분석(합성어같은것도 나누기) + 품사 태깅 : 단어/품사
# for wp in f:
#     print(wp)
print("-----")

g = o.pos(sentence, stem=True) # 형태소 분석(합성어같은것도 나누기 + 동사 원형) + 품사 태깅 : (단어, 품사)
print(g)
# Out:
# 네네 집체를 교육시간으로 보고 비대면은 그냥 프로젝트 멘토링으로 생각해도 될듯해요. 클라우드 환경위에 ai 플랫폼 구성해서 사업하고있는듯 해요. 선생님 봤을때 이거 난이도가 어때요? 비전공자 기준과, 우리 개발자 과정 수료생 듣는다 했을때? 에이ㅋㅋㅋ
# ['네네', '네네 집체', '교육시간', '보고', '보고 비대면', '그냥', '그냥 프로젝트', '그냥 프로젝트 멘토링', '생각', '클라우드', '클라우드 환경위', 'ai', 'ai 플랫폼', 'ai 플랫폼 구성', '사업', '선생님', '선생님 봤을때', '선생님 봤을때 이거', '선생님 봤을때 이거 난이도', '비전공자', '비전공자 기준', '우리', '우리 개발자', '우리 개발자 과정', '우리 개발자 과정 수료생', '에이', '집체', '교육', '시간', '대면', '프로젝트', '멘토링', '환경', '플랫폼', '구성', '이거', '난이도', '전공자', '기준', '개발자', '과정', '수료']
# ['네네', '집체', '를', '교육', '시간', '으로', '보고', '비', '대면', '은', '그냥', '프로젝트', '멘토링', '으로', '생각', '해도', '될듯', '해', '요', '.', '클라우드', '환경', '위', '에', 'ai', '플랫폼', '구성', '해서', '사업', '하고있는듯', '해', '요', '.', '선생님', '봤을', '때', '이', '거', '난이도', '가', '어때요', '?', '비', '전공자', '기준', '과', ',', '우리', '개발자', '과정', '수료', '생', '듣는다', '했을', '때', '?', '에이', 'ㅋㅋㅋㅋ']
# ...
