# %%
from konlpy.tag import Okt

o = Okt()

f = open("./Users/teacher02/Jan23_1_Text/naverNews.txt", "r", encoding="utf-8")

verbs = ""
for line in f.readlines():
    line = line.replace("\n","")
    line = o.normalize(line)
    for w, p in o.pos(line, stem=True):
        if p == "Verb":
            verbs += w + " "
f.close()

print(verbs)
# Out:
# 대다 맞다 알다 밝히다 낮추다 높이다 가다 보다 이르다 하다 받다 대다 내리다 알다 하다 받다 늘어나다 쏠리다 하다 배우다 따다 먹다 않다 쓰러지다 두르다 자다 가다 하다 몰다 넣다 박다 내다 지다 닮다 보여주다 올라가다 버티다 물다 도망가다 맞다 들다 돌리다 크다 들다 사로자다 크다 휘청이다 대다 숨지다 막히다 하다 알다 뿌리치다 개다 덮다 몰리다 생기다 앞두다 모르다 터지다 올라가다 버티다 보듬다 되다 닫다 하다 하다 기죽다 쏘다 망치다 울리다 하다 막다 막히다 불다 드러눕다 하다 사라지다 팔리다 물다 뚫다 되다 오다 하다 돼다 적다 되다 내놓다 이다 대다 대다 박다 올라가다 버티다 보여주다 먹다 나오다 말다 엇갈리다 넣다 하다 받다 불다 하다 개다 빼다 좋아지다 기대다 터지다 이다 끄다 묻다 줄이다 가르다 대다 깨다 막히다 않다 받다 하다 되다 받다 숨지다 되다 빼다 하다 해주다 하다 되다 하다 오르다 바꾸다 달아오르다 따르다 대다 앞두다 받다 오다 돼다 들다 하다 나서다 내다 하다 받다 들어오다 메다 돼다 하다 안다 숨지다 부르다 숨지다 만나다 오다 막다 심다 들다 보다 가보다 대다 올라가다 버티다 숨지다 돌보다 받다 숨기다 돌보다 지워지다 받다 하다 않다 대다 되다 대다 대다 올라가다 버티다 찾다 숨지다 자다 가다 가다 하다 하다 던지다 대다 찾다 하다 잠들다 늘다 보다 가다 깨다 하다 하다 나아지다 않다 가다 떨어지다 오르다 빠지다 보다 하다 하다 나오다 하다 알다 대다 하다 서다 올라가다 버티다 끄다 보다 떨어지다 잇다 대다 빠지다 하다 넘다 쏟아지다 하다 알다 나오다 숨지다 넘다 뿌리치다 개다 이다 잠들다 하다 하다 살다 쓴다 보다 하다 하다 하다 들키다 버리다 해주다 살피다 막다 올라가다 버티다 하다 훔치다 마시다 보다 쓰러지다 대다 믿다 줍다 줍다 개다 하다 돼다 보다 싸다 하다 끄다 모르다 보다 달라지다 받다 적다 먹다 하다 하다 내다 해보다 늘다 받다 대다 맞다 적다 심다 찾다 숨지다 뻗다 이다 오다 무너지다 막히다 늘리다 대다 찾다 하다 잠들다 자다 가다 가다 하다 되다 닫다 하다 하다 기죽다 쏘다 망치다 울리다 나서다 내다 되다 하다 하다 되다 하다 오르다 바꾸다 휘청이다 대다 숨지다 뚫다 하다 끄다 모르다 보다 달라지다 받다 줄이다 가르다 하다 배우다 따다 먹다 않다 쓰러지다 개다 하다 돼다 보다 싸다 하다 하다 숨지다 만나다 오다 크다 들다 사로자다 크다 막다 되다 대다 대다 들다 맞서다 말다 대다 빠지다 하다 넘다 쏟아지다 하다 알다 나오다 숨지다 되다 빼다 하다 해주다 가다 맞다 올라가다 버티다 하다 훔치다 마시다 보다 쓰러지다 돌보다 받다 숨기다 돌보다 지워지다 대다 숨지다 받다 들어오다 낮추다 높이다 가다 보다 보듬다 하다 막다 대다 깨다 막히다 않다 받다 올라가다 버티다 끄다 보다 떨어지다 잇다 막히다 불다 드러눕다 하다 사라지다 대다 하다 살피다 막다 막히다 알다 살다 쓴다 보다 하다 몰다 넣다 박다 내다 지다 팔리다 물다 받다 보내다 대다 들키다 버리다 해주다 넣다 하다 받다 불다 개다 들다 하다 받다 하다 않다 대다 보여주다 되다 오다 하다 돼다 적다 몰리다 대다 믿다 줍다 줍다 하다 알다 받다 늘어나다 쏠리다 나오다 알다 잠들다 하다 대다 하다 살다 하다 싶다 하다 서다 하다 이르다 하다 하다 던지다 대다 막다 터지다 이다 끄다 묻다 이다 대다 대다 막히다 하다 알다 받다 오다 돼다 대다 올라가다 버티다 숨지다 생기다 앞두다 모르다 터지다 실리다 내리다 알다 하다 닮다 들다 보다 하다 버리다 알다 늘다 보다 가다 깨다 하다 하다 나아지다 않다 붙다 박다 보다 하다 하다 나오다 날아가다 하다 되다 받다 숨지다 앞두다 올라가다 버티다 찾다 숨지다 뿌리치다 개다 덮다 뛰다 물다 도망가다 맞다 들다 돌리다 두르다 자다 가다 넘다 뿌리치다 개다 이다 하다

# %%
# %pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.19.3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from wordcloud) (2.2.6)
# Requirement already satisfied: pillow in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from wordcloud) (12.1.0)
# Requirement already satisfied: matplotlib in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=3 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.6-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.2/526.2 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from wordcloud.wordcloud import WordCloud

wc = WordCloud(font_path="./Users/teacher02/Jan23_1_Text/malgun.ttf").generate(verbs)
plt.imshow(wc)
plt.show()
