# %%
# GradientDescent 
#       L = e1 + e2 + e3 + ... + e10000000
#       모든 데이터를 다 고려하니 -> 느림
#       local minimum
#랜덤하게
# SGD(Stochastic GD)
#       e1, e2, e3, ..., e10000000
#       중에서 1개만 빼서 L로
#       나머지 중에서 랜덤하게 1개만 빼서 L로
#       ...반복
#       하나만 보니까 빠르고
#       의외성 생겨서 local minimum 해결가능
#       
# mini-batch SGD
#       SGD는 데이터를 하나만 보니 
#           -> 너무 성급하게 방향결정 
#           -> 파닥거림
#       -> 하나만 보지말고 몇개씩 보자
#           마침 동시에 여러개 처리 가능한 GPU있으니
#           batch size=2로 지정하면 한번에 2개씩 보자
#           batch size=10000000으로 지정하면 -> GD?
#           아무리 GPU가 있어도 동시에 1000만개는 불가
#
# momentum
#       그 전단계의 Gradient값을 추가로 넣어서 : 관성
#       -> 움직이는 값이 줄고
#       -> 직교x, 더 다이렉트하게 최적의 값을 향해
#
# RMSProp(Root Mean Squared Propagation)
#       x, y 각각 누적된 G값으로 나눠서 -> x,y를 동등하게 해서 의외성을 노려보자

# Adam(ADAptive Momentum estimation)
#       GD기반
#       Momentum + RMSProp
#       움직이는 방향은 Momentum
#       값은 RMSProp

# parameter : AI가 찾아내야하는 변수
#   Weight, bias
# hyperParameter : 사람이 지정해줘야하는 변수
#   learning rate : GD갈때 얼마씩 갈거냐
#   batch size : 데이터를 몇개씩 볼거냐
#   epoch : 전체데이터 다 보는걸 몇 번 반복
