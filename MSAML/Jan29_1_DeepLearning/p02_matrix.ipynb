# %%
# 행렬 덧셈 : 같은 자리에 있는것끼리 더하기
#   -> 두 행렬 모양이 같아야, 결과는 그 모양
# [[1 2]    10 20    1+10 2+20   [[11 22]
# [3 4]  +  30 40  = 3+30 4+40 = [33 44]
# [5 6]]    50 60    5+50 6+60   [55 66]]
# (3x2)     (3x2)                (3x2)

# 행렬 곱셈 : ???
#   -> (a x b) * (c x d)라면
#   b=c같아야 계산가능, 결과는 (a x d)
# [[1 2]   10 20   [[1*10+2*30  1*20+2*40]
# [3 4]  * 30 40 = [3*10+4*30  3*20+4*40]        
# [5 6]]           [5*10+6*30  5*20+6*40]]
# (3x2)    (2x2)   (3x2)
