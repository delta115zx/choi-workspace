# %%
# 인공신경망 : 행렬계산

# 1차원 : [1 10] x W + b -> 1
# 2차원(grayscale) 
# [
#   [255 0 255]
#   [0 255 0]    x W + b -> 1
#   [255 0 255]
# ]
# 3차원(color)
# [
#   [[255 255 255] [0 0 0] [255 255 255]]
#   [[0 0 0] [255 255 255] [0 0 0]]         x W + b -> 1
#   [[255 255 255] [0 0 0] [255 255 255]]
# ]
# 4차원(영상)
# -> 차원수를 줄여서 1차원으로

import cv2

a = cv2.imread("./Users/teacher02/Jan23_2_Image/android_normal.png", cv2.IMREAD_COLOR)
a = a.flatten()
print(len(a))

# 1. Tensorflow 2.x/PyTorch 자체적으로 flatten기능 있음
# 2. 냅다 펴면 위치정보는? -> CNN
# Out:
# 8700
