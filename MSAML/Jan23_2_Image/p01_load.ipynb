# %%
# 인공신경망 : 행렬계산 + 회귀를 통해 최적의 W, b찾는거
# 데이터 : 글자, 숫자, 이미지, 영상, 음성, ...
#   컴은 전자기기 -> 모든 데이터는 전기신호(흐름/안흐름) -> 2진수
#   데이터를 인코딩/디코딩만 가능하다면

# %%
# %pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 70.1 MB/s eta 0:00:00:00:010:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Windows환경 : 경로에 한글있으면 인식불가
import cv2

a = cv2.imread("./Users/teacher02/Jan23_2_Image/test.png", cv2.IMREAD_GRAYSCALE)
print(a)

print("-----")

b = cv2.imread("./Users/teacher02/Jan23_2_Image/test.png", cv2.IMREAD_COLOR) # 픽셀 하나를 [B G R]
b = cv2.cvtColor(b, cv2.COLOR_BGR2RGB) # BGR -> RGB
print(b)
# Out:
# [[255 255 255 255 255]
#  [255   0   0 255 255]
#  [255 255   0   0 255]
#  [255 255 255   0 255]
#  [255 255 255 255 255]]
# -----
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [  0   0   0]
#   [  0   0   0]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [  0   0   0]
#   [  0   0   0]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [  0   0   0]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
