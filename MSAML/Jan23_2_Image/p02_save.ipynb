# %%
import cv2
import matplotlib.pyplot as plt

a = cv2.imread("./Users/teacher02/Jan23_2_Image/android_normal.png", cv2.IMREAD_GRAYSCALE)
print(a)

plt.imshow(a)
plt.show()

cv2.imwrite("./Users/teacher02/Jan23_2_Image/android2.png", a)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# True
